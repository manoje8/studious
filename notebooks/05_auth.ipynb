# %%
from medici.api.utils_api import create_access_token, hash_password, validate_token, verify_password

# %%
password = "hola"

# %%
hashed_pass = hash_password(password)
hashed_pass

# %%
check_pass = verify_password(password, hashed_pass)

# %%
check_pass

# %%
access_token = create_access_token("Roop", role="admin", expire_hours=1, metadata={})

# %%
access_token

# %%
val_token = validate_token(access_token)

# %%
val_token
